# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import accuracy_score,classification_report
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df = pd.read_csv('advertising.csv')

# %%
df.head(1)
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1

# %%
y = df['Sales']
x = df.drop('Sales',axis=1)

# %%
scaler = StandardScaler()
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
clr = RandomForestRegressor(n_estimators=100,random_state=42)
clr.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = clr.predict(x_test)

# %%
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Absolute Error: 0.9171499999999992
# Mean Squared Error: 1.4368395500000006
# R-squared: 0.9535019934565436

# %%
plt.scatter(y_test,y_pred,edgecolors=(0,0,0))

# %%
dff = pd.read_csv('advertising.csv') 
l=[]
for i in range(3,len(dff),6):
    l.append([dff['TV'][i],dff['Radio'][i],dff['Newspaper'][i],dff['Sales'][i]])
df =pd.DataFrame(l,columns=['TV','Radio','Newspaper','Sales'])

# %%
df.to_csv('test.csv')

# %%
df= pd.read_csv('test.csv')
x= df.drop('Sales',axis=1)

# %%
x = x.drop('Unnamed: 0',axis=1)

# %%
x = scaler.transform(x)

# %%
y_pred1 = clr.predict(x)

# %%
for i in range(len(y_pred1)):
    print("expected :" , y_test.iloc[i]," got :", y_pred[i])
# Out:
# expected : 16.9  got : 17.298999999999992
# expected : 22.4  got : 22.482000000000003
# expected : 21.4  got : 19.770000000000014
# expected : 7.3  got : 6.784000000000007
# expected : 24.7  got : 22.961
# expected : 12.6  got : 13.47099999999998
# expected : 22.3  got : 22.594999999999974
# expected : 8.4  got : 9.579000000000015
# expected : 16.5  got : 16.88700000000001
# expected : 16.1  got : 16.792999999999996
# expected : 11.0  got : 7.499000000000002
# expected : 8.7  got : 10.327000000000016
# expected : 16.9  got : 17.345000000000006
# expected : 5.3  got : 5.132000000000005
# expected : 10.3  got : 11.500000000000005
# expected : 16.7  got : 16.902000000000008
# expected : 5.5  got : 6.5490000000000075
# expected : 16.6  got : 17.78799999999999
# expected : 11.3  got : 11.631999999999996
# expected : 18.9  got : 19.76600000000002
# expected : 19.7  got : 19.96499999999999
# expected : 12.5  got : 13.133999999999988
# expected : 10.9  got : 10.017999999999992
# ...
